# %%
import os
import sys
import signal
MDTF_ROOT = '/Users/tsj/Documents/climate/MDTF-diagnostics'
sys.path.append(MDTF_ROOT)
sys.argv = ['mdtf']

import shlex
from src import core, diagnostic, cli, util, data_sources, preprocessor

import dagster as dg

# %%
class dgLocalFileDataSource(data_sources.SampleLocalFileDataSource):
    def preprocess_data(self):
        """Hook to run the preprocessing function on all variables.
        """
        update = True
        # really a while-loop, but limit # of iterations to be safe
        for _ in range(5):
            if update:
                # fetch alternates for any vars that failed since last time
                self.fetch_data()
                update = False
            else:
                # preproc_harness starts here
                break
        else:
            # only hit this if we don't break
            raise util.DataRequestError(
                f"Too many iterations in preprocess_data() for {self.full_name}."
            )

    def request_data(self):
        """Top-level method to iteratively query, fetch and preprocess all data
        requested by PODs, switching to alternate requested data as needed.
        """
        # Call cleanup method if we're killed
        signal.signal(signal.SIGTERM, self.query_and_fetch_cleanup)
        signal.signal(signal.SIGINT, self.query_and_fetch_cleanup)
        self.pre_query_and_fetch_hook()
        try:
            self.preprocess_data()
        except Exception as exc:
            self.log.exception("%s at DataSource level: %r.",
                util.exc_descriptor(exc), exc)
        # clean up regardless of success/fail
        self.post_query_and_fetch_hook()
        for p in self.iter_children():
            for v in p.iter_children():
                if v.status == core.ObjectStatus.ACTIVE:
                    v.log.debug('Data request for %s completed succesfully.',
                        v.full_name)
                    # v.status = core.ObjectStatus.SUCCEEDED
                elif v.failed:
                    v.log.debug('Data request for %s failed.', v.full_name)
                else:
                    v.log.debug('Data request for %s not used.', v.full_name)
            if p.failed:
                p.log.debug('Data request for %s failed.', p.full_name)
            else:
                p.log.debug('Data request for %s completed succesfully.',
                    p.full_name)

# %%
@dg.solid(
    output_defs=[dg.OutputDefinition(name="case")]
)
def init_harness(context):
    os.chdir(MDTF_ROOT)
    cli_obj = cli.MDTFTopLevelArgParser(MDTF_ROOT, argv=context.solid_config['cli_args'])
    fmwk = cli_obj.dispatch()
    fmwk.DataSource = dgLocalFileDataSource

    # unroll framework.main()
    fmwk.cases = dict(list(fmwk.cases.items())[0:1])
    new_d = dict()
    for case_name, case_d in fmwk.cases.items():
        context.log.info(f"### {fmwk.full_name}: initializing case '{case_name}'.")
        case = fmwk.DataSource(case_d, parent=fmwk)
        case.setup()
        new_d[case_name] = case
    fmwk.cases = new_d
    # util.transfer_log_cache(close=True)
    for case_name, case in fmwk.cases.items():
        if not case.failed:
            context.log.info(f"### {fmwk.full_name}: requesting data for case '{case_name}'.")
            case.request_data()
            yield dg.Output(case, output_name='case')

@dg.solid(
    input_defs=[dg.InputDefinition(name="case")],
    output_defs=[dg.DynamicOutputDefinition(name="case_var")]
)
def query_fanout(context, case):
    vars_to_query = [
        v for v in case.iter_vars_only(active=True) \
            if v.stage < diagnostic.VarlistEntryStage.QUERIED
    ]
    context.log.debug(f"Query batch: [{', '.join(v.full_name for v in vars_to_query)}].")
    case.pre_query_hook(vars_to_query)
    for v in vars_to_query:
        yield dg.DynamicOutput(value=(case, v), mapping_key=v.name, output_name="case_var")

@dg.solid(
    input_defs=[dg.InputDefinition(name="case_v")],
    output_defs=[dg.OutputDefinition(name="v")]
)
def query_data(context, case_v):
    case, v = case_v
    try:
        context.log.info(f"Querying {v.translation}.")
        case.query_dataset(v) # sets v.data
        if not v.data:
            raise util.DataQueryEvent("No data found.", v)
        v.stage = diagnostic.VarlistEntryStage.QUERIED
    except util.DataQueryEvent as exc:
        v.deactivate(exc)
    except Exception as exc:
        chained_exc = util.chain_exc(exc,
            f"querying {v.translation} for {v.full_name}.",
            util.DataQueryEvent)
        v.deactivate(chained_exc)
    return v

@dg.solid(
    input_defs=[dg.InputDefinition(name="case"), dg.InputDefinition(name="vars_list")],
    output_defs=[dg.DynamicOutputDefinition(name="case_var")]
)
def fanin_select_fanout(context, case, vars_list):
    case.post_query_hook(vars_list)
    case.set_experiment()

    vars_to_fetch = [
        v for v in case.iter_vars_only(active=True) \
            if v.stage < diagnostic.VarlistEntryStage.FETCHED
    ]
    context.log.debug(f"Fetch batch: [{', '.join(v.full_name for v in vars_to_fetch)}].")
    case.pre_fetch_hook(vars_to_fetch)
    for v in vars_to_fetch:
        yield dg.DynamicOutput(value=(case, v), mapping_key=v.name, output_name="case_var")

@dg.solid(
    input_defs=[dg.InputDefinition(name="case_v")],
    output_defs=[dg.OutputDefinition(name="v")]
)
def fetch_data(context, case_v):
    case, v = case_v
    try:
        context.log.info(f"Fetching {str(v)}.")
        # fetch on a per-DataKey basis
        for d_key in v.iter_data_keys(status=core.ObjectStatus.ACTIVE):
            try:
                if not case.is_fetch_necessary(d_key):
                    continue
                v.log.debug(f"Fetching {str(d_key)}.")
                case.fetch_dataset(v, d_key)
            except Exception as exc:
                d_key.deactivate(exc)
                break # no point continuing
        # check if var received everything
        for d_key in v.iter_data_keys(status=core.ObjectStatus.ACTIVE):
            if not d_key.local_data:
                raise util.DataFetchEvent("Fetch failed.", d_key)
        v.stage = diagnostic.VarlistEntryStage.FETCHED
    except Exception as exc:
        chained_exc = util.chain_exc(exc,
            f"fetching data for {v.full_name}.",
            util.DataFetchEvent)
        v.deactivate(chained_exc)
    return v

@dg.solid(
    input_defs=[dg.InputDefinition(name="case"), dg.InputDefinition(name="vars_list")],
    output_defs=[dg.DynamicOutputDefinition(name="pod_var")]
)
def fanin_preproc_setup_fanout(context, case, vars_list):
    case.post_fetch_hook(vars_list)
    for pod in case.iter_children(status=core.ObjectStatus.ACTIVE):
        pod.preprocessor.setup(case, pod)

    for pv in case.iter_vars(active=True):
        if pv.var.stage < diagnostic.VarlistEntryStage.PREPROCESSED:
            yield dg.DynamicOutput(value=(pv.pod, pv.var), output_name="pod_var",
                mapping_key=f"{pv.pod.name}_{pv.var.name}")


@dg.solid(
    input_defs=[dg.InputDefinition(name="pod_var")],
    output_defs=[dg.OutputDefinition(name="v")]
)
def fetch_data(context, pod_var):
    pod, var = pod_var
    try:
        pvar.log.info("Preprocessing %s.", pv.var)
        pod.preprocessor.process(pv.var)
        var.stage = diagnostic.VarlistEntryStage.PREPROCESSED
    except Exception as exc:
        update = True
        self.log.exception("%s while preprocessing %s: %r",
            util.exc_descriptor(exc), pv.var.full_name, exc)
        for d_key in var.iter_data_keys(status=core.ObjectStatus.ACTIVE):
            var.deactivate_data_key(d_key, exc)







@dg.solid(
    input_defs=[dg.InputDefinition(name="case")],
    output_defs=[dg.DynamicOutputDefinition(name="pv")]
)
def mdtf_preproc_harness(context, case):
    for pv in case.iter_vars():
        print(pv.pod.name, pv.var.name, pv.var.status, pv.var.stage) #, pv.var.format_log())
    vars_to_process = [
        pv for pv in case.iter_vars(active=True) \
            if pv.var.stage < diagnostic.VarlistEntryStage.PREPROCESSED
    ]
    # if not vars_to_process:
    #     break # exit: processed everything or nothing active
    print(len(vars_to_process))
    for pod in case.iter_children(status=core.ObjectStatus.ACTIVE):
        print('XX', pod.name)
        pod.preprocessor.setup(case, pod)
    for pv in vars_to_process:
        try:
            print("Preprocessing {pv.var}")
            pv.var.stage = diagnostic.VarlistEntryStage.PREPROCESSED
            # pv.pod.preprocessor.process(pv.var)
            yield dg.DynamicOutput(pv, mapping_key=f"podvar{pv}")
        except Exception as exc:
            update = True
            context.log.exception(f"{util.exc_descriptor(exc)} while preprocessing {pv.var.full_name}")
            for d_key in pv.var.iter_data_keys(status=core.ObjectStatus.ACTIVE):
                pv.var.deactivate_data_key(d_key, exc)
            continue

@dg.solid(
    input_defs=[dg.InputDefinition(name="pv")],
    output_defs=[dg.OutputDefinition(name="var"), dg.OutputDefinition(name="preproc")]
)
def get_attrs(context, pv):
    yield dg.Output(pv.var, output_name="var")
    yield dg.Output(pv.pod.preprocessor, output_name="preproc")

@dg.solid(
    input_defs=[dg.InputDefinition(name="preproc"), dg.InputDefinition(name="var")],
    output_defs=[dg.OutputDefinition(name="ds")]
)
def load_ds(context, preproc, var):
    return preproc.load_ds(var)

@dg.solid(
    input_defs=[dg.InputDefinition(name="var"), dg.InputDefinition(name="ds")]
)
def crop_daterange(context, var, ds):
    func = preprocessor.CropDateRangeFunction(_,_)
    return func.process(var, ds)

@dg.solid(
    input_defs=[dg.InputDefinition(name="var"), dg.InputDefinition(name="ds")]
)
def precip_rate_to_flux(context, var, ds):
    func = preprocessor.PrecipRateToFluxFunction(_,_)
    return func.process(var, ds)

@dg.solid(
    input_defs=[dg.InputDefinition(name="var"), dg.InputDefinition(name="ds")]
)
def convert_units(context, var, ds):
    func = preprocessor.ConvertUnitsFunction(_,_)
    return func.process(var, ds)

@dg.solid(
    input_defs=[dg.InputDefinition(name="var"), dg.InputDefinition(name="ds")]
)
def extract_level(context, var, ds):
    func = preprocessor.ExtractLevelFunction(_,_)
    return func.process(var, ds)

@dg.solid(
    input_defs=[dg.InputDefinition(name="var"), dg.InputDefinition(name="ds")]
)
def rename_variables(context, var, ds):
    func = preprocessor.RenameVariablesFunction(_,_)
    return func.process(var, ds)

@dg.solid(
    input_defs=[
        dg.InputDefinition(name="preproc"),
        dg.InputDefinition(name="var"),
        dg.InputDefinition(name="ds")
    ]
)
def write_ds(context, preproc, var, ds):
    preproc.write_ds(var, ds)

@dg.composite_solid(
    input_defs=[dg.InputDefinition(name="pv")]
)
def preprocess_one_file(pv):
    var, preproc = get_attrs(pv)
    ds = load_ds(preproc, var)
    ds = crop_daterange(var, ds)
    ds = precip_rate_to_flux(var, ds)
    ds = convert_units(var, ds)
    ds = extract_level(var, ds)
    ds = rename_variables(var, ds)
    write_ds(preproc, var, ds)

# %%
@dg.pipeline
def test_preproc():
    mdtf_preproc_harness(mdtf_test_harness()).map(preprocess_one_file)

run_config = {
    "solids": {
        "mdtf_test_harness": {
            "config": {
                "cli_args": '-v -f="temp_test.jsonc" -p Wheeler_Kiladis',
            }
        }
    }
}
dg.execute_pipeline(test_preproc, run_config=run_config)
# Out:
# 2021-08-24 21:31:35 - dagster - DEBUG - test_preproc - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - 11992 - PIPELINE_START - Started execution of pipeline "test_preproc".
# 2021-08-24 21:31:35 - dagster - DEBUG - test_preproc - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - 11992 - ENGINE_EVENT - Executing steps in process (pid: 11992)
# 2021-08-24 21:31:35 - dagster - DEBUG - test_preproc - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - 11992 - ENGINE_EVENT - Starting initialization of resources [io_manager].
# 2021-08-24 21:31:35 - dagster - DEBUG - test_preproc - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - 11992 - ENGINE_EVENT - Finished initialization of resources [io_manager].
# 2021-08-24 21:31:35 - dagster - DEBUG - test_preproc - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - 11992 - mdtf_test_harness - LOGS_CAPTURED - Started capturing logs for solid: mdtf_test_harness.
# 2021-08-24 21:31:35 - dagster - DEBUG - test_preproc - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - 11992 - mdtf_test_harness - STEP_START - Started execution of step "mdtf_test_harness".
# 2021-08-24 21:31:35 - dagster - INFO - system - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - mdtf_test_harness - ### MDTFFramework: initializing case 'QBOi.EXP1.AMIP.001'.
# 2021-08-24 21:31:35 - dagster - INFO - system - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - mdtf_test_harness - ### MDTFFramework: requesting data for case 'QBOi.EXP1.AMIP.001'.
# /Users/tsj/Documents/climate/MDTF-diagnostics/src/data_manager.py:1008: FutureWarning: Passing 'suffixes' which cause duplicate columns {'sample_dataset_x'} in the result is deprecated and will raise a MergeError in a future version.
#   expt_df = pd.merge(
# 2021-08-24 21:31:35 - dagster - DEBUG - test_preproc - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - 11992 - mdtf_test_harness - STEP_OUTPUT - Yielded output "case" of type "Any". (Type check passed).
# 2021-08-24 21:31:35 - dagster - DEBUG - test_preproc - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - 11992 - mdtf_test_harness - HANDLED_OUTPUT - Handled output "case" using IO manager "io_manager"
# 2021-08-24 21:31:35 - dagster - DEBUG - test_preproc - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - 11992 - mdtf_test_harness - STEP_SUCCESS - Finished execution of step "mdtf_test_harness" in 285ms.
# 2021-08-24 21:31:35 - dagster - DEBUG - test_preproc - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - 11992 - mdtf_preproc_harness - LOGS_CAPTURED - Started capturing logs for solid: mdtf_preproc_harness.
# 2021-08-24 21:31:35 - dagster - DEBUG - test_preproc - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - 11992 - mdtf_preproc_harness - STEP_START - Started execution of step "mdtf_preproc_harness".
# 2021-08-24 21:31:35 - dagster - DEBUG - test_preproc - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - 11992 - mdtf_preproc_harness - LOADED_INPUT - Loaded input "case" using input manager "io_manager", from output "case" of step "mdtf_test_harness"
# 2021-08-24 21:31:35 - dagster - DEBUG - test_preproc - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - 11992 - mdtf_preproc_harness - STEP_INPUT - Got input "case" of type "Any". (Type check passed).
# 2021-08-24 21:31:35 - dagster - INFO - system - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - mdtf_preproc_harness - Solid mdtf_preproc_harness did not fire outputs {'pv'}
# 2021-08-24 21:31:35 - dagster - DEBUG - test_preproc - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - 11992 - mdtf_preproc_harness - STEP_SUCCESS - Finished execution of step "mdtf_preproc_harness" in 1.52ms.
# 2021-08-24 21:31:35 - dagster - DEBUG - test_preproc - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - 11992 - ENGINE_EVENT - Finished steps in process (pid: 11992) in 303ms
# 2021-08-24 21:31:35 - dagster - DEBUG - test_preproc - d7b86c17-0853-4dd0-81ff-65b0638e2f23 - 11992 - PIPELINE_SUCCESS - Finished execution of pipeline "test_preproc".
# Wheeler_Kiladis rlut succeeded fetched
# Wheeler_Kiladis pr failed inited
# Wheeler_Kiladis pr succeeded fetched
# Wheeler_Kiladis omega500 succeeded fetched
# Wheeler_Kiladis omega500 inactive inited
# Wheeler_Kiladis u200 succeeded fetched
# Wheeler_Kiladis u200 inactive inited
# Wheeler_Kiladis u850 succeeded fetched
# Wheeler_Kiladis u850 inactive inited
# 0
# XX Wheeler_Kiladis

# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# /var/folders/9p/n9mfs2mx0k7_v0yn1ns408qr0000gn/T/ipykernel_10803/2412284341.py in <module>
#      12     }
#      13 }
# ---> 14 dg.execute_pipeline(test_preproc, run_config=run_config)
#
# ~/anaconda2/envs/FRE-dagster-dev/lib/python3.8/site-packages/dagster/core/execution/api.py in execute_pipeline(pipeline, run_config, mode, preset, tags, solid_selection, instance, raise_on_error)
#     365
#     366     with ephemeral_instance_if_missing(instance) as execute_instance:
# --> 367         return _logged_execute_pipeline(
#     368             pipeline,
#     369             instance=execute_instance,
#
# ~/anaconda2/envs/FRE-dagster-dev/lib/python3.8/site-packages/dagster/core/telemetry.py in wrap(*args, **kwargs)
#      82         start_time = datetime.datetime.now()
#      83         log_action(instance=instance, action=f.__name__ + "_started", client_time=start_time)
# ---> 84         result = f(*args, **kwargs)
#      85         end_time = datetime.datetime.now()
#      86         log_action(
#
# ~/anaconda2/envs/FRE-dagster-dev/lib/python3.8/site-packages/dagster/core/execution/api.py in _logged_execute_pipeline(pipeline, instance, run_config, mode, preset, tags, solid_selection, raise_on_error)
#     416     )
#     417
# --> 418     return execute_run(
#     419         pipeline,
#     420         pipeline_run,
#
# ~/anaconda2/envs/FRE-dagster-dev/lib/python3.8/site-packages/dagster/core/execution/api.py in execute_run(pipeline, pipeline_run, instance, raise_on_error)
#     218         ),
#     219     )
# --> 220     event_list = list(_execute_run_iterable)
#     221
#     222     return PipelineExecutionResult(
#
# ~/anaconda2/envs/FRE-dagster-dev/lib/python3.8/site-packages/dagster/core/execution/api.py in __iter__(self)
#     833             try:
#     834                 if self.pipeline_context:  # False if we had a pipeline init failure
# --> 835                     yield from self.iterator(
#     836                         execution_plan=self.execution_plan,
#     837                         pipeline_context=self.pipeline_context,
#
# ~/anaconda2/envs/FRE-dagster-dev/lib/python3.8/site-packages/dagster/core/execution/api.py in pipeline_execution_iterator(pipeline_context, execution_plan)
#     754     generator_closed = False
#     755     try:
# --> 756         for event in pipeline_context.executor.execute(pipeline_context, execution_plan):
#     757             if event.is_step_failure:
#     758                 failed_steps.append(event.step_key)
#
# ~/anaconda2/envs/FRE-dagster-dev/lib/python3.8/site-packages/dagster/core/executor/in_process.py in execute(self, pipeline_context, execution_plan)
#      36
#      37         with time_execution_scope() as timer_result:
# ---> 38             yield from iter(
#      39                 ExecuteRunWithPlanIterable(
#      40                     execution_plan=pipeline_context.execution_plan,
#
# ~/anaconda2/envs/FRE-dagster-dev/lib/python3.8/site-packages/dagster/core/execution/api.py in __iter__(self)
#     833             try:
#     834                 if self.pipeline_context:  # False if we had a pipeline init failure
# --> 835                     yield from self.iterator(
#     836                         execution_plan=self.execution_plan,
#     837                         pipeline_context=self.pipeline_context,
#
# ~/anaconda2/envs/FRE-dagster-dev/lib/python3.8/site-packages/dagster/core/execution/plan/execute_plan.py in inner_plan_execution_iterator(pipeline_context, execution_plan)
#      67                 )
#      68
# ---> 69                 for step_event in check.generator(_dagster_event_sequence_for_step(step_context)):
#      70                     check.inst(step_event, DagsterEvent)
#      71                     step_event_list.append(step_event)
#
# ~/anaconda2/envs/FRE-dagster-dev/lib/python3.8/site-packages/dagster/core/execution/plan/execute_plan.py in _dagster_event_sequence_for_step(step_context)
#     191             step_events = core_dagster_event_sequence_for_step(step_context)
#     192
# --> 193         for step_event in check.generator(step_events):
#     194             yield step_event
#     195
#
# ~/anaconda2/envs/FRE-dagster-dev/lib/python3.8/site-packages/dagster/core/execution/plan/execute_step.py in core_dagster_event_sequence_for_step(step_context)
#     319         # It is important for this loop to be indented within the
#     320         # timer block above in order for time to be recorded accurately.
# --> 321         for user_event in check.generator(
#     322             _step_output_error_checked_user_event_sequence(step_context, user_event_sequence)
#     323         ):
#
# ~/anaconda2/envs/FRE-dagster-dev/lib/python3.8/site-packages/dagster/core/execution/plan/execute_step.py in _step_output_error_checked_user_event_sequence(step_context, user_event_sequence)
#      63     seen_mapping_keys: Dict[str, Set[str]] = defaultdict(set)
#      64
# ---> 65     for user_event in user_event_sequence:
#      66         if not isinstance(user_event, (Output, DynamicOutput)):
#      67             yield user_event
#
# ~/anaconda2/envs/FRE-dagster-dev/lib/python3.8/site-packages/dagster/core/execution/plan/compute.py in execute_core_compute(step_context, inputs, compute_fn)
#     136
#     137     all_results = []
# --> 138     for step_output in _yield_compute_results(step_context, inputs, compute_fn):
#     139         yield step_output
#     140         if isinstance(step_output, (DynamicOutput, Output)):
#
# ~/anaconda2/envs/FRE-dagster-dev/lib/python3.8/site-packages/dagster/core/execution/plan/compute.py in _yield_compute_results(step_context, inputs, compute_fn)
#     109         user_event_generator = gen_from_async_gen(user_event_generator)
#     110
# --> 111     for event in iterate_with_context(
#     112         lambda: solid_execution_error_boundary(
#     113             DagsterExecutionStepExecutionError,
#
# ~/anaconda2/envs/FRE-dagster-dev/lib/python3.8/site-packages/dagster/utils/__init__.py in iterate_with_context(context_fn, iterator)
#     381         with context_fn():
#     382             try:
# --> 383                 next_output = next(iterator)
#     384             except StopIteration:
#     385                 return
#
# /var/folders/9p/n9mfs2mx0k7_v0yn1ns408qr0000gn/T/ipykernel_10803/1944767959.py in mdtf_test_harness(context)
#      28     os.chdir(MDTF_ROOT)
#      29     cli_obj = cli.MDTFTopLevelArgParser(MDTF_ROOT)
# ---> 30     fmwk = cli_obj.dispatch(shlex.split(context.solid_config['cli_args']))
#      31     fmwk.DataSource = dgLocalFileDataSource
#      32
#
# ~/Documents/climate/MDTF-diagnostics/src/cli.py in dispatch(self, args)
#    1215         assert len(config.subcommands) == 1
#    1216         cmd = tuple(config.subcommands.values())[0]
# -> 1217         return cmd.call(self)
#    1218
#    1219
#
# ~/Documents/climate/MDTF-diagnostics/src/cli.py in call(self, *args, **kwargs)
#     553         """
#     554         cls_ = self.import_target()
# --> 555         instance = cls_(*args, **kwargs)
#     556         return instance
#     557
#
# ~/Documents/climate/MDTF-diagnostics/src/util/basic.py in __call__(cls, *args, **kwargs)
#      37     """
#      38     def __call__(cls, *args, **kwargs):
# ---> 39         instance = abc.ABCMeta.__call__(cls, *args, **kwargs)
#      40         abstract_attributes = set([])
#      41         for attr in dir(instance):
#
# ~/Documents/climate/MDTF-diagnostics/src/core.py in __init__(self, cli_obj)
#     774                 self.code_root, "logging.jsonc", site=cli_obj.site
#     775             )
# --> 776             self.configure(cli_obj, pod_info_tuple, log_config)
#     777         except Exception as exc:
#     778             tb_exc = traceback.TracebackException(*(sys.exc_info()))
#
# ~/Documents/climate/MDTF-diagnostics/src/core.py in configure(self, cli_obj, pod_info_tuple, log_config)
#     795         self._cli_post_parse_hook(cli_obj)
#     796         self.dispatch_classes(cli_obj)
# --> 797         self.parse_mdtf_args(cli_obj, pod_info_tuple)
#     798         # init singletons
#     799         config = ConfigManager(cli_obj, pod_info_tuple,
#
# ~/Documents/climate/MDTF-diagnostics/src/core.py in parse_mdtf_args(self, cli_obj, pod_info_tuple)
#     841         pod_list = cli_obj.config.pop('pods', [])
#     842         self.pod_list = self.parse_pod_list(pod_list, pod_info_tuple)
# --> 843         self.parse_case_list(cli_obj, pod_info_tuple)
#     844
#     845     def parse_flags(self, cli_obj):
#
# ~/Documents/climate/MDTF-diagnostics/src/core.py in parse_case_list(self, cli_obj, pod_info_tuple)
#     962                 "model run information.\nReceived:"
#     963                 f"\n{util.pretty_print_json(case_list_in)}"))
# --> 964             util.exit_handler(code=1)
#     965
#     966     def verify_paths(self, config, p):
#
# ~/Documents/climate/MDTF-diagnostics/src/util/exceptions.py in exit_handler(code, msg)
#      31     if msg:
#      32         print(msg)
# ---> 33     sys.exit(code)
#      34
#      35 def chain_exc(exc, new_msg, new_exc_class=None):
#
# SystemExit: 1

# %%
os.chdir(MDTF_ROOT)
util.logs.initial_log_config()
cli_obj = cli.MDTFTopLevelArgParser(MDTF_ROOT)
fmwk = cli_obj.dispatch('-v -f="temp_test.jsonc" -p Wheeler_Kiladis')
#print(fmwk)
#fmwk.DataSource = dgLocalFileDataSource

# %%
fmwk = cli_obj.dispatch(args='-v -f="temp_test.jsonc" -p Wheeler_Kiladis')
# Out:
# x1
# x2
# x3
# x4 data_manager
# x4 environment_manager
# x4 runtime_manager
# x4 output_manager
# x5
# x6 CLICommand(name='run', entry_point='src.core:MDTFFramework', help='Run the framework on model data.', cli_file='src/cli_template.jsonc', cli=CLIParser(prog=None, usage='mdtf run [options] [CASE_ROOT_DIR]', description='Runs diagnostics in the NOAA Model Diagnostics Task Force (MDTF) package. See\ndocumentation at https://mdtf-diagnostics.rtfd.io.\n\nThe scripts runs specified diagnostics on data at CASE_ROOT_DIR, using\nconfiguration set on the command line and/or through a file passed via\n--input_file.', epilog=None, arguments=[CLIArgument(name='CASE_ROOT_DIR', action=<class 'src.cli.RecordDefaultsAction'>, nargs='?', const=None, default=None, type=<class 'str'>, choices=None, required=None, help='Root directory of model data to analyze.', metavar='CASE_ROOT_DIR', dest=None, arg_flags=['CASE_ROOT_DIR'], is_positional=True, short_name=None, hidden=False)], argument_groups=[CLIArgumentGroup(title='PATHS', description="Location of input and output data. If a relative path is given, it's resolved relative to the MDTF-diagnostics code directory.", arguments=[CLIArgument(name='OBS_DATA_ROOT', action=<class 'src.cli.PathAction'>, nargs=None, const=None, default=None, type=None, choices=None, required=False, help='Parent directory containing observational data used by individual PODs.', metavar='<DIR>', dest='OBS_DATA_ROOT', arg_flags=['--OBS_DATA_ROOT', '--OBS-DATA-ROOT'], is_positional=False, short_name=None, hidden=False), CLIArgument(name='CASE_ROOT_DIR', action=<class 'src.cli.RecordDefaultsAction'>, nargs=None, const=None, default=None, type=None, choices=None, required=False, help='Alternate way to specify root directory of model data (with a flag instead of a positional argument.)', metavar='<DIR>', dest='flag_root_dir', arg_flags=['--CASE_ROOT_DIR', '--CASE-ROOT-DIR'], is_positional=False, short_name=None, hidden=False), CLIArgument(name='WORKING_DIR', action=<class 'src.cli.PathAction'>, nargs=None, const=None, default=None, type=None, choices=None, required=False, help='Working directory. Defaults to output directory if unspecified.', metavar='<DIR>', dest='WORKING_DIR', arg_flags=['--WORKING_DIR', '-w', '--WORKING-DIR'], is_positional=False, short_name='w', hidden=False), CLIArgument(name='OUTPUT_DIR', action=<class 'src.cli.PathAction'>, nargs=None, const=None, default=None, type=None, choices=None, required=False, help='Directory to write output files.', metavar='<DIR>', dest='OUTPUT_DIR', arg_flags=['--OUTPUT_DIR', '-o', '--OUTPUT-DIR'], is_positional=False, short_name='o', hidden=False)]), CLIArgumentGroup(title='DATA', description='Settings describing the input model data.', arguments=[CLIArgument(name='convention', action=<class 'src.cli.RecordDefaultsAction'>, nargs=None, const=None, default='CMIP', type=None, choices=None, required=False, help='Variable name/unit convention used in model data.', metavar='<convention>', dest='convention', arg_flags=['--convention', '-c'], is_positional=False, short_name='c', hidden=False), CLIArgument(name='strict', action=<class 'src.cli.RecordDefaultsAction'>, nargs=None, const=None, default=False, type=None, choices=None, required=False, help='If set, disables experiment selection heuristics and raises error if experiment not uniquely specified by user input.', metavar=None, dest='strict', arg_flags=['--strict'], is_positional=False, short_name=None, hidden=False), CLIArgument(name='disable_preprocessor', action=<class 'src.cli.RecordDefaultsAction'>, nargs=None, const=None, default=False, type=None, choices=None, required=False, help='If set, disables metadata checks and unit conversion by the framework prior to POD execution. This is only provided as a workaround for input data which is known to have incorrect metadata.', metavar=None, dest='disable_preprocessor', arg_flags=['--disable_preprocessor', '--disable-preprocessor'], is_positional=False, short_name=None, hidden=False), CLIArgument(name='overwrite_file_metadata', action=<class 'src.cli.RecordDefaultsAction'>, narg ...
# x1
# x2 <class 'src.core.MDTFFramework'> (ArgParserHarness(prog='mdtf', usage='mdtf run [options] [CASE_ROOT_DIR]', description='Runs diagnostics in the NOAA Model Diagnostics Task Force (MDTF) package. See\ndocumentation at https://mdtf-diagnostics.rtfd.io.\n\nThe scripts runs specified diagnostics on data at CASE_ROOT_DIR, using\nconfiguration set on the command line and/or through a file passed via\n--input_file.', formatter_class=<class 'src.cli.CustomHelpFormatter'>, conflict_handler='error', add_help=True),) {}
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# WARNING: /Users/tsj/anaconda2/envs/FRE-dagster-dev/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3449: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
